# %%
import numpy as np
import pandas as pd
import sys
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
plt.rcParams["font.sans-serif"] = "Arial" 

import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.DataFrame([['left', 'dorsal', 185+166],
                   ['left', 'ventral', 36+92],
                   ['right', 'dorsal', 238+160],
                   ['right', 'ventral',77+71]], columns=['hemisphere', 'd', 'value'])
print(df)

palette = ['#718bdf', '#e84d60']  # 颜色设置
fig, ax = plt.subplots(figsize=(4, 3), dpi=300, facecolor="black")
plt.style.use('dark_background')
sns.barplot(data=df, 
            y='value', 
            x='d',
            hue='hemisphere', 
            palette=palette,
            dodge=True)  # 使用 dodge 来分开不同的 hemisphere
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.xlabel('', fontsize=20)
plt.ylabel('', fontsize=20)
plt.title('A45-AuCM', fontsize=20)
plt.legend(fontsize=12)
plt.show()
# Out:
#   hemisphere        d  value
# 0       left   dorsal    351
# 1       left  ventral    128
# 2      right   dorsal    398
# 3      right  ventral    148

# %%
df = pd.DataFrame([['left', 'dorsal', 1243+2569],
                   ['left', 'ventral', 70+132],
                   ['right', 'dorsal', 521+1521],
                   ['right', 'ventral',5+2]], columns=['hemisphere', 'd', 'value'])
print(df)

palette = ['#718bdf', '#e84d60']  # 颜色设置
fig, ax = plt.subplots(figsize=(4, 3), dpi=300, facecolor="black")
plt.style.use('dark_background')
sns.barplot(data=df, 
            y='value', 
            x='d',
            hue='hemisphere', 
            palette=palette,
            dodge=True)  # 使用 dodge 来分开不同的 hemisphere
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.xlabel('', fontsize=20)
plt.ylabel('', fontsize=20)
plt.title('A45-Tpt', fontsize=20)
#plt.legend(fontsize=12)
legend = plt.legend()
legend.set_visible(False)
plt.show()
# Out:
#   hemisphere        d  value
# 0       left   dorsal   3812
# 1       left  ventral    202
# 2      right   dorsal   2042
# 3      right  ventral      7
